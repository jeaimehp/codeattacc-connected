# %% [markdown]
# # Read and Plot Data Example
#
# This notebook shows a way to read in a file with comma seperated values (csv) and then plot the results.
#
# ### List the files in the working directory (the directory your program can see)

# %%
print ("Current working directory:")
# !pwd
print ("\nAvailable files:")
# !ls *.csv
# Out:
# Current working directory:
# /home/pi/codeattacc-connected/Notebook
#
# Available files:
# Full-Turkey-Creek-Sensor-Data.csv  SAMPLE-rpiz_sensor-1-20180719-sensorlog.csv

# %%
# Insert the file name
datafile = 'SAMPLE-rpiz_sensor-1-20180719-sensorlog.csv'

# %%
# Libraries needed to do the work
import pandas as pd # The Pandas library makes it easier to work with data
import numpy as np # Numpy adds additional numerical methods (math functions)
import matplotlib.pyplot as plt
from matplotlib import style

style.use('fivethirtyeight')

# Read in the csv datafile from above, and save it to the Pandas "dataframe" named sensor_data
# and add the header names to match the data
sensor_data = pd.read_csv(datafile, names=['Timestamp','Light','R','G','B','Temperature','Humidity','A0','A1','A2','A3','A4'])

# Print the first 5 lines of the dataframe named sensor_data
sensor_data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-15bb34914242> in <module>
#       1 # Libraries needed to do the work
# ----> 2 import pandas as pd # The Pandas library makes it easier to work with data
#       3 import numpy as np # Numpy adds additional numerical methods (math functions)
#       4 import matplotlib.pyplot as plt
#       5 from matplotlib import style
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Graph the the Timestamp on the x axis and Light on the y axis
sensor_data.plot(x="Timestamp",y="Light")

# %%
# Graph the the Timestamp on the x axis and Temperature on the y axis
sensor_data.plot(x="Timestamp",y="Temperature")

# %%
# Graph the the Timestamp on the x axis and Humidity on the y axis
sensor_data.plot(x="Timestamp",y="Humidity")

# %%
# Graph the the Timestamp on the x axis and A0 pin on the y axis
sensor_data.plot(x="Timestamp",y="A0")
